# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential
from keras.models import load_model

import joblib


df = yf.download('BTC-USD', start='2010-01-01',
                end=date.today())

#data.to_csv('../data/historical_yfinance/btc_usd.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2778 entries, 2014-09-17 to 2022-04-25
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2778 non-null   float64
#  1   High       2778 non-null   float64
#  2   Low        2778 non-null   float64
#  3   Close      2778 non-null   float64
#  4   Adj Close  2778 non-null   float64
#  5   Volume     2778 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 151.9 KB

# %%
#df = pd.read_csv('../data/historical_yfinance/btc_usd.csv')

# %%
df = df.reset_index()
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 2773 2022-04-21  41371.515625  42893.582031  40063.828125  40527.363281
# 2774 2022-04-22  40525.863281  40777.757812  39315.417969  39740.320312
# 2775 2022-04-23  39738.722656  39935.859375  39352.203125  39486.730469
# 2776 2022-04-24  39478.375000  39845.925781  39233.539062  39469.292969
# 2777 2022-04-25  39472.605469  40491.753906  38338.378906  40458.308594
#
#          Adj Close       Volume
# 0       457.334015     21056800
# 1       424.440002     34483200
# 2       394.795990     37919700
# 3       408.903992     36863600
# 4       398.821014     26580100
# ...            ...          ...
# 2773  40527.363281  35372786395
# 2774  39740.320312  28011716745
# 2775  39486.730469  16138021249
# 2776  39469.292969  17964398167
# 2777  40458.308594  35445730570
#
# [2778 rows x 7 columns]

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(df['Close'].values.reshape(-1,1))

# %%
prediction_days = 60 #Number of past days to take into account to calculate the prediction

x_train, y_train = [], []
for x in range (prediction_days, len(scaled_data)):
    x_train.append(scaled_data[x-prediction_days:x, 0])
    y_train.append(scaled_data[x, 0])

x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50)) 
model.add(Dropout(0.2))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=25, batch_size=32)
# Out:
# Epoch 1/25
# 85/85 [==============================] - 9s 57ms/step - loss: 0.0062
# Epoch 2/25
# 85/85 [==============================] - 4s 50ms/step - loss: 0.0024
# Epoch 3/25
# 85/85 [==============================] - 4s 52ms/step - loss: 0.0022
# Epoch 4/25
# 85/85 [==============================] - 5s 61ms/step - loss: 0.0018
# Epoch 5/25
# 85/85 [==============================] - 4s 48ms/step - loss: 0.0016
# Epoch 6/25
# 85/85 [==============================] - 4s 50ms/step - loss: 0.0016
# Epoch 7/25
# 85/85 [==============================] - 4s 50ms/step - loss: 0.0016
# Epoch 8/25
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0016
# Epoch 9/25
# 85/85 [==============================] - 4s 51ms/step - loss: 0.0014
# Epoch 10/25
# 85/85 [==============================] - 4s 51ms/step - loss: 0.0012
# Epoch 11/25
# 85/85 [==============================] - 4s 51ms/step - loss: 0.0016
# Epoch 12/25
# 85/85 [==============================] - 4s 52ms/step - loss: 0.0013
# Epoch 13/25
# 85/85 [==============================] - 4s 53ms/step - loss: 0.0013
# Epoch 14/25
# 85/85 [==============================] - 4s 52ms/step - loss: 0.0015
# Epoch 15/25
# 85/85 [==============================] - 4s 53ms/step - loss: 0.0010
# Epoch 16/25
# 85/85 [==============================] - 5s 53ms/step - loss: 0.0011
# Epoch 17/25
# 85/85 [==============================] - 5s 53ms/step - loss: 0.0012
# Epoch 18/25
# 85/85 [==============================] - 5s 53ms/step - loss: 9.4206e-04
# Epoch 19/25
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0011
# Epoch 20/25
# 85/85 [==============================] - 4s 51ms/step - loss: 9.7386e-04
# Epoch 21/25
# 85/85 [==============================] - 4s 51ms/step - loss: 9.8596e-04
# Epoch 22/25
# 85/85 [==============================] - 4s 53ms/step - loss: 0.0011
# Epoch 23/25
# 85/85 [==============================] - 4s 50ms/step - loss: 0.0011
# Epoch 24/25
# 85/85 [==============================] - 5s 54ms/step - loss: 9.8135e-04
# Epoch 25/25
# 85/85 [==============================] - 4s 48ms/step - loss: 9.6600e-04

# %%
test_data = yf.download('BTC-USD', start='2020-01-01',
                end=date.today())
test_data = test_data.reset_index()
actual_prices = test_data['Close'].values
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
total_dataset = pd.concat((df['Close'], test_data['Close']), axis=0)

# %%
model_inputs = total_dataset[len(total_dataset)-len(test_data)- prediction_days:].values
model_inputs = model_inputs.reshape(-1,1)
model_inputs = scaler.fit_transform(model_inputs)

# %%
x_test = []
for x in range (prediction_days, len(model_inputs)):
    x_test.append(model_inputs[x-prediction_days:x,0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1],1))

# %%
prediction_prices = model.predict(x_test)
prediction_prices = scaler.inverse_transform(prediction_prices)

# %%
prediction_days = 60 #Number of past days to take into account to calculate the prediction

def save_neural_network(symbol_crypto)
crypto_mapping = {"Bitcoin": "BTC-USD", 
                "Ethereum": "ETH-USD", 
                "Tether": "USDT-USD", 
                "BNB": "BNB-USD", 
                "USD Coin": "USDC-USD", 
                "Solana": "SOL-USD", 
                "XRP": "XRP-USD", 
                "Terra": "LUNA-USD", 
                "Cardano": "ADA-USD", 
                "Avalanche": "AVAX-USD", 
                "Dogecoin": "DOGE-USD", 
                "TerraUSD": "UST-USD", 
                "Binance USD": "BUSD-USD", 
                "Shiba Inu": "SHIB-USD",
                "Wrapped Bitcoin": "WBTC-USD"}
                
for i in crypto_mapping:
    print (crypto_mapping[i])
    symbol_crypto = crypto_mapping[i]

    df = yf.download(symbol_crypto, start='2010-01-01',
                    end=date.today())
    df = df.reset_index()
    df['Date'] = pd.to_datetime(df['Date'])


    scaler = MinMaxScaler(feature_range=(0,1))
    scaled_data = scaler.fit_transform(df['Close'].values.reshape(-1,1))


    x_train, y_train = [], []
    for x in range (prediction_days, len(scaled_data)):
        x_train.append(scaled_data[x-prediction_days:x, 0])
        y_train.append(scaled_data[x, 0])

    x_train, y_train = np.array(x_train), np.array(y_train)
    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))


    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50)) 
    model.add(Dropout(0.2))
    model.add(Dense(units=1))

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(x_train, y_train, epochs=25, batch_size=32)

    #Save Scaler and Model

    scaler_filename = "../data/scalers_neural_network/" + symbol_crypto + "_scaler.save"
    model_filename = "../data/models/" + symbol_crypto + "_keras.h5"

    joblib.dump(scaler, scaler_filename) 
    model.save(model_filename)
# Out:
# BTC-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 85/85 [==============================] - 11s 46ms/step - loss: 0.0070
# Epoch 2/25
# 85/85 [==============================] - 4s 48ms/step - loss: 0.0021
# Epoch 3/25
# 85/85 [==============================] - 4s 49ms/step - loss: 0.0020
# Epoch 4/25
# 85/85 [==============================] - 4s 47ms/step - loss: 0.0018
# Epoch 5/25
# 85/85 [==============================] - 4s 48ms/step - loss: 0.0019
# Epoch 6/25
# 85/85 [==============================] - 4s 51ms/step - loss: 0.0014
# Epoch 7/25
# 85/85 [==============================] - 4s 50ms/step - loss: 0.0017
# Epoch 8/25
# 85/85 [==============================] - 4s 51ms/step - loss: 0.0014
# Epoch 9/25
# 85/85 [==============================] - 4s 51ms/step - loss: 0.0015
# Epoch 10/25
# 85/85 [==============================] - 4s 52ms/step - loss: 0.0014
# Epoch 11/25
# 85/85 [==============================] - 4s 51ms/step - loss: 0.0015
# Epoch 12/25
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0012
# Epoch 13/25
# 85/85 [==============================] - 5s 53ms/step - loss: 0.0014
# Epoch 14/25
# 85/85 [==============================] - 4s 52ms/step - loss: 0.0011
# Epoch 15/25
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0012
# Epoch 16/25
# 85/85 [==============================] - 5s 60ms/step - loss: 0.0012
# Epoch 17/25
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0011
# Epoch 18/25
# 85/85 [==============================] - 5s 58ms/step - loss: 0.0014
# Epoch 19/25
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0011
# Epoch 20/25
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0010
# Epoch 21/25
# 85/85 [==============================] - 5s 54ms/step - loss: 9.4980e-04
# Epoch 22/25
# 85/85 [==============================] - 4s 53ms/step - loss: 0.0011
# Epoch 23/25
# 85/85 [==============================] - 5s 54ms/step - loss: 9.7578e-04
# Epoch 24/25
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0010
# Epoch 25/25
# 85/85 [==============================] - 4s 52ms/step - loss: 9.2268e-04
# ETH-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 50/50 [==============================] - 7s 47ms/step - loss: 0.0141
# Epoch 2/25
# 50/50 [==============================] - 3s 50ms/step - loss: 0.0038
# Epoch 3/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0032
# Epoch 4/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0035
# Epoch 5/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0033
# Epoch 6/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0026
# Epoch 7/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0029
# Epoch 8/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0024
# Epoch 9/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0024
# Epoch 10/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0023
# Epoch 11/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0026
# Epoch 12/25
# 50/50 [==============================] - 3s 63ms/step - loss: 0.0022
# Epoch 13/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0022
# Epoch 14/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0021
# Epoch 15/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0040
# Epoch 16/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0020
# Epoch 17/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0020
# Epoch 18/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0021
# Epoch 19/25
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0019
# Epoch 20/25
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0019
# Epoch 21/25
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0017
# Epoch 22/25
# 50/50 [==============================] - 3s 59ms/step - loss: 0.0017
# Epoch 23/25
# 50/50 [==============================] - 3s 60ms/step - loss: 0.0016
# Epoch 24/25
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0015
# Epoch 25/25
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0016
# USDT-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 50/50 [==============================] - 8s 49ms/step - loss: 0.0089
# Epoch 2/25
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0026
# Epoch 3/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0025
# Epoch 4/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0024
# Epoch 5/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0021
# Epoch 6/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0024
# Epoch 7/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0023
# Epoch 8/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0023
# Epoch 9/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0022
# Epoch 10/25
# 50/50 [==============================] - 3s 60ms/step - loss: 0.0021
# Epoch 11/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0020
# Epoch 12/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0019
# Epoch 13/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0020
# Epoch 14/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0020
# Epoch 15/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0020
# Epoch 16/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0019
# Epoch 17/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0018
# Epoch 18/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0018
# Epoch 19/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0018
# Epoch 20/25
# 50/50 [==============================] - 3s 62ms/step - loss: 0.0018
# Epoch 21/25
# 50/50 [==============================] - 3s 60ms/step - loss: 0.0018
# Epoch 22/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0017
# Epoch 23/25
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0017
# Epoch 24/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0017
# Epoch 25/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0017
# BNB-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 50/50 [==============================] - 7s 43ms/step - loss: 0.0173
# Epoch 2/25
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0040
# Epoch 3/25
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0037
# Epoch 4/25
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0037
# Epoch 5/25
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0032
# Epoch 6/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0032
# Epoch 7/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0027
# Epoch 8/25
# 50/50 [==============================] - 3s 60ms/step - loss: 0.0028
# Epoch 9/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0031
# Epoch 10/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0023
# Epoch 11/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0027
# Epoch 12/25
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0022
# Epoch 13/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0022
# Epoch 14/25
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0026
# Epoch 15/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0024
# Epoch 16/25
# 50/50 [==============================] - 3s 59ms/step - loss: 0.0024
# Epoch 17/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0023
# Epoch 18/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0019
# Epoch 19/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0019
# Epoch 20/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0017
# Epoch 21/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0018
# Epoch 22/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0021
# Epoch 23/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0016
# Epoch 24/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0020
# Epoch 25/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0016
# USDC-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 39/39 [==============================] - 6s 46ms/step - loss: 0.0202
# Epoch 2/25
# 39/39 [==============================] - 2s 47ms/step - loss: 0.0055
# Epoch 3/25
# 39/39 [==============================] - 2s 50ms/step - loss: 0.0050
# Epoch 4/25
# 39/39 [==============================] - 2s 53ms/step - loss: 0.0051
# Epoch 5/25
# 39/39 [==============================] - 2s 55ms/step - loss: 0.0052
# Epoch 6/25
# 39/39 [==============================] - 2s 55ms/step - loss: 0.0052
# Epoch 7/25
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0049
# Epoch 8/25
# 39/39 [==============================] - 2s 57ms/step - loss: 0.0047
# Epoch 9/25
# 39/39 [==============================] - 2s 56ms/step - loss: 0.0044
# Epoch 10/25
# 39/39 [==============================] - 2s 58ms/step - loss: 0.0050
# Epoch 11/25
# 39/39 [==============================] - 2s 58ms/step - loss: 0.0041
# Epoch 12/25
# 39/39 [==============================] - 2s 56ms/step - loss: 0.0042
# Epoch 13/25
# 39/39 [==============================] - 2s 55ms/step - loss: 0.0044
# Epoch 14/25
# 39/39 [==============================] - 2s 54ms/step - loss: 0.0040
# Epoch 15/25
# 39/39 [==============================] - 2s 54ms/step - loss: 0.0039
# Epoch 16/25
# 39/39 [==============================] - 2s 55ms/step - loss: 0.0040
# Epoch 17/25
# 39/39 [==============================] - 2s 54ms/step - loss: 0.0043
# Epoch 18/25
# 39/39 [==============================] - 2s 55ms/step - loss: 0.0038
# Epoch 19/25
# 39/39 [==============================] - 2s 55ms/step - loss: 0.0038
# Epoch 20/25
# 39/39 [==============================] - 2s 56ms/step - loss: 0.0040
# Epoch 21/25
# 39/39 [==============================] - 2s 54ms/step - loss: 0.0038
# Epoch 22/25
# 39/39 [==============================] - 2s 52ms/step - loss: 0.0038
# Epoch 23/25
# 39/39 [==============================] - 2s 52ms/step - loss: 0.0036
# Epoch 24/25
# 39/39 [==============================] - 2s 51ms/step - loss: 0.0034
# Epoch 25/25
# 39/39 [==============================] - 2s 56ms/step - loss: 0.0035
# SOL-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 22/22 [==============================] - 5s 44ms/step - loss: 0.0404
# Epoch 2/25
# 22/22 [==============================] - 1s 47ms/step - loss: 0.0091
# Epoch 3/25
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0078
# Epoch 4/25
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0061
# Epoch 5/25
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0050
# Epoch 6/25
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0056
# Epoch 7/25
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0047
# Epoch 8/25
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0049
# Epoch 9/25
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0041
# Epoch 10/25
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0045
# Epoch 11/25
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0038
# Epoch 12/25
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0040
# Epoch 13/25
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0037
# Epoch 14/25
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0039
# Epoch 15/25
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0038
# Epoch 16/25
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0041
# Epoch 17/25
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0035
# Epoch 18/25
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0033
# Epoch 19/25
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0040
# Epoch 20/25
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0033
# Epoch 21/25
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0038
# Epoch 22/25
# 22/22 [==============================] - 1s 64ms/step - loss: 0.0032
# Epoch 23/25
# 22/22 [==============================] - 2s 69ms/step - loss: 0.0033
# Epoch 24/25
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0034
# Epoch 25/25
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0030
# XRP-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 50/50 [==============================] - 6s 42ms/step - loss: 0.0029
# Epoch 2/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0016
# Epoch 3/25
# 50/50 [==============================] - 5s 94ms/step - loss: 0.0013
# Epoch 4/25
# 50/50 [==============================] - 4s 79ms/step - loss: 0.0012
# Epoch 5/25
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0011
# Epoch 6/25
# 50/50 [==============================] - 3s 60ms/step - loss: 0.0011
# Epoch 7/25
# 50/50 [==============================] - 3s 59ms/step - loss: 9.3057e-04
# Epoch 8/25
# 50/50 [==============================] - 4s 88ms/step - loss: 8.9716e-04
# Epoch 9/25
# 50/50 [==============================] - 3s 67ms/step - loss: 8.8424e-04
# Epoch 10/25
# 50/50 [==============================] - 3s 54ms/step - loss: 8.3077e-04
# Epoch 11/25
# 50/50 [==============================] - 3s 54ms/step - loss: 7.8315e-04
# Epoch 12/25
# 50/50 [==============================] - 3s 52ms/step - loss: 7.9011e-04
# Epoch 13/25
# 50/50 [==============================] - 2s 49ms/step - loss: 7.0859e-04
# Epoch 14/25
# 50/50 [==============================] - 2s 47ms/step - loss: 6.7695e-04
# Epoch 15/25
# 50/50 [==============================] - 2s 45ms/step - loss: 8.3449e-04
# Epoch 16/25
# 50/50 [==============================] - 2s 46ms/step - loss: 6.3523e-04
# Epoch 17/25
# 50/50 [==============================] - 2s 46ms/step - loss: 6.3910e-04
# Epoch 18/25
# 50/50 [==============================] - 2s 47ms/step - loss: 6.0237e-04
# Epoch 19/25
# 50/50 [==============================] - 2s 46ms/step - loss: 6.7219e-04
# Epoch 20/25
# 50/50 [==============================] - 2s 50ms/step - loss: 6.3219e-04
# Epoch 21/25
# 50/50 [==============================] - 3s 53ms/step - loss: 6.1226e-04
# Epoch 22/25
# 50/50 [==============================] - 3s 54ms/step - loss: 5.8789e-04
# Epoch 23/25
# 50/50 [==============================] - 3s 52ms/step - loss: 5.5790e-04
# Epoch 24/25
# 50/50 [==============================] - 3s 52ms/step - loss: 5.8898e-04
# Epoch 25/25
# 50/50 [==============================] - 2s 48ms/step - loss: 5.8925e-04
# LUNA-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 50/50 [==============================] - 7s 39ms/step - loss: 0.0024
# Epoch 2/25
# 50/50 [==============================] - 2s 41ms/step - loss: 0.0012
# Epoch 3/25
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0011
# Epoch 4/25
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0013
# Epoch 5/25
# 50/50 [==============================] - 2s 48ms/step - loss: 9.4314e-04
# Epoch 6/25
# 50/50 [==============================] - 2s 49ms/step - loss: 9.2947e-04
# Epoch 7/25
# 50/50 [==============================] - 3s 51ms/step - loss: 9.0129e-04
# Epoch 8/25
# 50/50 [==============================] - 2s 50ms/step - loss: 8.7167e-04
# Epoch 9/25
# 50/50 [==============================] - 2s 49ms/step - loss: 9.5689e-04
# Epoch 10/25
# 50/50 [==============================] - 2s 48ms/step - loss: 7.9729e-04
# Epoch 11/25
# 50/50 [==============================] - 2s 47ms/step - loss: 8.9962e-04
# Epoch 12/25
# 50/50 [==============================] - 2s 49ms/step - loss: 8.1658e-04
# Epoch 13/25
# 50/50 [==============================] - 2s 47ms/step - loss: 7.1867e-04
# Epoch 14/25
# 50/50 [==============================] - 2s 47ms/step - loss: 7.1858e-04
# Epoch 15/25
# 50/50 [==============================] - 2s 47ms/step - loss: 7.6617e-04
# Epoch 16/25
# 50/50 [==============================] - 2s 47ms/step - loss: 6.0758e-04
# Epoch 17/25
# 50/50 [==============================] - 2s 47ms/step - loss: 6.1554e-04
# Epoch 18/25
# 50/50 [==============================] - 2s 47ms/step - loss: 7.5414e-04
# Epoch 19/25
# 50/50 [==============================] - 2s 48ms/step - loss: 6.3643e-04
# Epoch 20/25
# 50/50 [==============================] - 2s 48ms/step - loss: 7.0109e-04
# Epoch 21/25
# 50/50 [==============================] - 2s 47ms/step - loss: 5.9068e-04
# Epoch 22/25
# 50/50 [==============================] - 2s 48ms/step - loss: 7.6656e-04
# Epoch 23/25
# 50/50 [==============================] - 2s 46ms/step - loss: 7.7678e-04
# Epoch 24/25
# 50/50 [==============================] - 2s 45ms/step - loss: 6.0560e-04
# Epoch 25/25
# 50/50 [==============================] - 2s 45ms/step - loss: 7.4970e-04
# ADA-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 50/50 [==============================] - 6s 39ms/step - loss: 0.0092
# Epoch 2/25
# 50/50 [==============================] - 2s 42ms/step - loss: 0.0027
# Epoch 3/25
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0023
# Epoch 4/25
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0022
# Epoch 5/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0025
# Epoch 6/25
# 50/50 [==============================] - 2s 50ms/step - loss: 0.0022
# Epoch 7/25
# 50/50 [==============================] - 3s 51ms/step - loss: 0.0018
# Epoch 8/25
# 50/50 [==============================] - 2s 50ms/step - loss: 0.0019
# Epoch 9/25
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0022
# Epoch 10/25
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0020
# Epoch 11/25
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0018
# Epoch 12/25
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0018
# Epoch 13/25
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0017
# Epoch 14/25
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0017
# Epoch 15/25
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0016
# Epoch 16/25
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0021
# Epoch 17/25
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0016
# Epoch 18/25
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0016
# Epoch 19/25
# 50/50 [==============================] - 3s 65ms/step - loss: 0.0015
# Epoch 20/25
# 50/50 [==============================] - 3s 62ms/step - loss: 0.0015
# Epoch 21/25
# 50/50 [==============================] - 3s 70ms/step - loss: 0.0013
# Epoch 22/25
# 50/50 [==============================] - 3s 66ms/step - loss: 0.0013
# Epoch 23/25
# 50/50 [==============================] - 3s 67ms/step - loss: 0.0014
# Epoch 24/25
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0015
# Epoch 25/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0014
# AVAX-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 17/17 [==============================] - 6s 47ms/step - loss: 0.0530
# Epoch 2/25
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0151
# Epoch 3/25
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0089
# Epoch 4/25
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0096
# Epoch 5/25
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0091
# Epoch 6/25
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0093
# Epoch 7/25
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0086
# Epoch 8/25
# 17/17 [==============================] - 1s 56ms/step - loss: 0.0084
# Epoch 9/25
# 17/17 [==============================] - 1s 59ms/step - loss: 0.0083
# Epoch 10/25
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0075
# Epoch 11/25
# 17/17 [==============================] - 1s 56ms/step - loss: 0.0074
# Epoch 12/25
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0067
# Epoch 13/25
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0067
# Epoch 14/25
# 17/17 [==============================] - 1s 56ms/step - loss: 0.0068
# Epoch 15/25
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0066
# Epoch 16/25
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0065
# Epoch 17/25
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0060
# Epoch 18/25
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0060
# Epoch 19/25
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0056
# Epoch 20/25
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0061
# Epoch 21/25
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0057
# Epoch 22/25
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0059
# Epoch 23/25
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0059
# Epoch 24/25
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0050
# Epoch 25/25
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0051
# DOGE-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 50/50 [==============================] - 6s 43ms/step - loss: 0.0055
# Epoch 2/25
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0026
# Epoch 3/25
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0024
# Epoch 4/25
# 50/50 [==============================] - 3s 59ms/step - loss: 0.0024
# Epoch 5/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0018
# Epoch 6/25
# 50/50 [==============================] - 3s 59ms/step - loss: 0.0019
# Epoch 7/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0016
# Epoch 8/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0016
# Epoch 9/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0016
# Epoch 10/25
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0016
# Epoch 11/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0018
# Epoch 12/25
# 50/50 [==============================] - 3s 55ms/step - loss: 0.0013
# Epoch 13/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0016
# Epoch 14/25
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0013
# Epoch 15/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0015
# Epoch 16/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0014
# Epoch 17/25
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0012
# Epoch 18/25
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0012
# Epoch 19/25
# 50/50 [==============================] - 3s 51ms/step - loss: 0.0012
# Epoch 20/25
# 50/50 [==============================] - 3s 51ms/step - loss: 0.0012
# Epoch 21/25
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0012
# Epoch 22/25
# 50/50 [==============================] - 3s 51ms/step - loss: 0.0014
# Epoch 23/25
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0012
# Epoch 24/25
# 50/50 [==============================] - 3s 53ms/step - loss: 9.6334e-04
# Epoch 25/25
# 50/50 [==============================] - 3s 54ms/step - loss: 9.1981e-04
# UST-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 15/15 [==============================] - 5s 43ms/step - loss: 0.1797
# Epoch 2/25
# 15/15 [==============================] - 1s 41ms/step - loss: 0.0240
# Epoch 3/25
# 15/15 [==============================] - 1s 41ms/step - loss: 0.0101
# Epoch 4/25
# 15/15 [==============================] - 1s 43ms/step - loss: 0.0087
# Epoch 5/25
# 15/15 [==============================] - 1s 44ms/step - loss: 0.0080
# Epoch 6/25
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0072
# Epoch 7/25
# 15/15 [==============================] - 1s 47ms/step - loss: 0.0074
# Epoch 8/25
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0065
# Epoch 9/25
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0069
# Epoch 10/25
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0080
# Epoch 11/25
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0064
# Epoch 12/25
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0062
# Epoch 13/25
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0059
# Epoch 14/25
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0053
# Epoch 15/25
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0058
# Epoch 16/25
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0049
# Epoch 17/25
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0052
# Epoch 18/25
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0052
# Epoch 19/25
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0049
# Epoch 20/25
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0050
# Epoch 21/25
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0049
# Epoch 22/25
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0050
# Epoch 23/25
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0047
# Epoch 24/25
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0045
# Epoch 25/25
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0042
# BUSD-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 28/28 [==============================] - 6s 42ms/step - loss: 0.0185
# Epoch 2/25
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0032
# Epoch 3/25
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0028
# Epoch 4/25
# 28/28 [==============================] - 1s 47ms/step - loss: 0.0026
# Epoch 5/25
# 28/28 [==============================] - 1s 51ms/step - loss: 0.0027
# Epoch 6/25
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0023
# Epoch 7/25
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0024
# Epoch 8/25
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0023
# Epoch 9/25
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0024
# Epoch 10/25
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0022
# Epoch 11/25
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0021
# Epoch 12/25
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0022
# Epoch 13/25
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0023
# Epoch 14/25
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0022
# Epoch 15/25
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0022
# Epoch 16/25
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0021
# Epoch 17/25
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0022
# Epoch 18/25
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0023
# Epoch 19/25
# 28/28 [==============================] - 1s 52ms/step - loss: 0.0021
# Epoch 20/25
# 28/28 [==============================] - 1s 52ms/step - loss: 0.0021
# Epoch 21/25
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0020
# Epoch 22/25
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0021
# Epoch 23/25
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0021
# Epoch 24/25
# 28/28 [==============================] - 1s 53ms/step - loss: 0.0021
# Epoch 25/25
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0021
# SHIB-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 18/18 [==============================] - 5s 42ms/step - loss: 0.0229
# Epoch 2/25
# 18/18 [==============================] - 1s 59ms/step - loss: 0.0069
# Epoch 3/25
# 18/18 [==============================] - 1s 45ms/step - loss: 0.0064
# Epoch 4/25
# 18/18 [==============================] - 1s 47ms/step - loss: 0.0059
# Epoch 5/25
# 18/18 [==============================] - 1s 49ms/step - loss: 0.0050
# Epoch 6/25
# 18/18 [==============================] - 1s 57ms/step - loss: 0.0057
# Epoch 7/25
# 18/18 [==============================] - 1s 54ms/step - loss: 0.0050
# Epoch 8/25
# 18/18 [==============================] - 1s 53ms/step - loss: 0.0050
# Epoch 9/25
# 18/18 [==============================] - 1s 54ms/step - loss: 0.0047
# Epoch 10/25
# 18/18 [==============================] - 1s 55ms/step - loss: 0.0048
# Epoch 11/25
# 18/18 [==============================] - 1s 55ms/step - loss: 0.0046
# Epoch 12/25
# 18/18 [==============================] - 1s 54ms/step - loss: 0.0047
# Epoch 13/25
# 18/18 [==============================] - 1s 55ms/step - loss: 0.0041
# Epoch 14/25
# 18/18 [==============================] - 1s 55ms/step - loss: 0.0044
# Epoch 15/25
# 18/18 [==============================] - 1s 57ms/step - loss: 0.0039
# Epoch 16/25
# 18/18 [==============================] - 1s 55ms/step - loss: 0.0042
# Epoch 17/25
# 18/18 [==============================] - 1s 55ms/step - loss: 0.0039
# Epoch 18/25
# 18/18 [==============================] - 1s 54ms/step - loss: 0.0042
# Epoch 19/25
# 18/18 [==============================] - 1s 55ms/step - loss: 0.0038
# Epoch 20/25
# 18/18 [==============================] - 1s 54ms/step - loss: 0.0035
# Epoch 21/25
# 18/18 [==============================] - 1s 54ms/step - loss: 0.0032
# Epoch 22/25
# 18/18 [==============================] - 1s 54ms/step - loss: 0.0036
# Epoch 23/25
# 18/18 [==============================] - 1s 54ms/step - loss: 0.0034
# Epoch 24/25
# 18/18 [==============================] - 1s 54ms/step - loss: 0.0034
# Epoch 25/25
# 18/18 [==============================] - 1s 55ms/step - loss: 0.0037
# WBTC-USD
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# 36/36 [==============================] - 6s 42ms/step - loss: 0.0238
# Epoch 2/25
# 36/36 [==============================] - 2s 43ms/step - loss: 0.0061
# Epoch 3/25
# 36/36 [==============================] - 2s 53ms/step - loss: 0.0052
# Epoch 4/25
# 36/36 [==============================] - 2s 51ms/step - loss: 0.0045
# Epoch 5/25
# 36/36 [==============================] - 2s 52ms/step - loss: 0.0045
# Epoch 6/25
# 36/36 [==============================] - 2s 54ms/step - loss: 0.0044
# Epoch 7/25
# 36/36 [==============================] - 2s 54ms/step - loss: 0.0048
# Epoch 8/25
# 36/36 [==============================] - 2s 55ms/step - loss: 0.0047
# Epoch 9/25
# 36/36 [==============================] - 2s 54ms/step - loss: 0.0041
# Epoch 10/25
# 36/36 [==============================] - 2s 56ms/step - loss: 0.0036
# Epoch 11/25
# 36/36 [==============================] - 2s 54ms/step - loss: 0.0036
# Epoch 12/25
# 36/36 [==============================] - 2s 54ms/step - loss: 0.0035
# Epoch 13/25
# 36/36 [==============================] - 2s 53ms/step - loss: 0.0032
# Epoch 14/25
# 36/36 [==============================] - 2s 52ms/step - loss: 0.0033
# Epoch 15/25
# 36/36 [==============================] - 2s 52ms/step - loss: 0.0029
# Epoch 16/25
# 36/36 [==============================] - 2s 51ms/step - loss: 0.0035
# Epoch 17/25
# 36/36 [==============================] - 2s 51ms/step - loss: 0.0027
# Epoch 18/25
# 36/36 [==============================] - 2s 58ms/step - loss: 0.0026
# Epoch 19/25
# 36/36 [==============================] - 2s 52ms/step - loss: 0.0032
# Epoch 20/25
# 36/36 [==============================] - 2s 53ms/step - loss: 0.0030
# Epoch 21/25
# 36/36 [==============================] - 2s 52ms/step - loss: 0.0029
# Epoch 22/25
# 36/36 [==============================] - 2s 61ms/step - loss: 0.0027
# Epoch 23/25
# 36/36 [==============================] - 2s 54ms/step - loss: 0.0025
# Epoch 24/25
# 36/36 [==============================] - 2s 51ms/step - loss: 0.0024
# Epoch 25/25
# 36/36 [==============================] - 2s 51ms/step - loss: 0.0022

# %%
scaler_filename = "../data/scalers_neural_network/" + symbol_crypto + "_scaler.save"
model_filename = "../data/models/" + symbol_crypto + "_keras.h5"

joblib.dump(scaler, scaler_filename) 
model.save(model_filename)

# %%
#Load scaler and model

scaler1 = joblib.load(scaler_filename) 
model1 = load_model(model_filename)


test_data = yf.download('BTC-USD', start='2020-01-01',
                end=date.today())
test_data = test_data.reset_index()
actual_prices = test_data['Close'].values


total_dataset = pd.concat((df['Close'], test_data['Close']), axis=0)


model_inputs = total_dataset[len(total_dataset)-len(test_data)- prediction_days:].values
model_inputs = model_inputs.reshape(-1,1)
model_inputs = scaler1.fit_transform(model_inputs)


x_test = []
for x in range (prediction_days, len(model_inputs)):
    x_test.append(model_inputs[x-prediction_days:x,0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1],1))


prediction_prices = model1.predict(x_test)
prediction_prices = scaler1.inverse_transform(prediction_prices)


#Creating results dataframe and saving them as a CSV file
df1 = pd.DataFrame(test_data.Date)
df1['prediction_prices'] = prediction_prices
df1['actual_prices'] = actual_prices

prediction_file_path = '../data/predictions_neural_network/'+ symbol_crypto + '.csv'
df1.to_csv(prediction_file_path)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import plotly.graph_objects as go
import plotly.offline as pyo

df2 = pd.read_csv(prediction_file_path, index_col=[0])

# Create figure
fig = go.Figure()

actual_prices_plot = go.Scatter(name='Actual prices',x=df2.Date, y=df2.actual_prices)
prediction_prices_plot = go.Scatter(name='Predicted prices',x=df2.Date, y=df2.prediction_prices)

# Set title
fig.update_layout(title_text="Bitcoin price prediction")

data = [actual_prices_plot,prediction_prices_plot]
fig = dict(data=data)
pyo.iplot(fig, filename='temp1')

# %%
#Predict Next Day
real_data = [model_inputs[len(model_inputs) - prediction_days:len(model_inputs) +1 , 0]]
real_data = np.array(real_data)
real_data = np.reshape(real_data, (real_data.shape[0], real_data.shape[1], 1))
prediction = model.predict(real_data)
prediction = scaler.inverse_transform(prediction)
print(prediction)
# Out:
# [[40537.547]]

# %%
next_day_prediction(model_inputs, model1,scaler1)
# Out:
# 40537.547
